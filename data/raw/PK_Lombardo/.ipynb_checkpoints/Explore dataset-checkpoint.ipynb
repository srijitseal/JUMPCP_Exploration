# %%
import pandas as pd

# %%
df = pd.read_csv("PK_Lombardo.csv")
df
# Out:
#                         Name  \
# 0                     ?-hANP
# 1                    (-)dOTC
# 2                    (+)dOTC
# 3                   1,3-DCQA
# 4          16-acetyl gitoxin
# ...                      ...
# 1347              Zonampanel
# 1348              Zoniporide
# 1349               Zopiclone
# 1350  Zoptarelin doxorubicin
# 1351             Zotarolimus
#
#                                                  smiles  human VDss (L/kg)  \
# 0     N1[C@H](C(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@H](C(...               0.20
# 1                    c1cn(c(=O)nc1N)[C@H]2CO[C@H](S2)CO               1.18
# 2                  c1cn(c(=O)nc1N)[C@@H]2CO[C@@H](S2)CO               0.84
# 3     O[C@@H]1C[C@@](C[C@@H](OC(=O)\C=C\c2ccc(O)c(O)...               0.79
# 4     C1([C@@H]2[C@@]3([C@@]([C@@H]4[C@@H]([C@@]5(CC...               0.78
# ...                                                 ...                ...
# 1347    OC(=O)CN1C(=O)C(=O)Nc2cc(c(cc12)n3ccnc3)N(=O)=O               0.19
# ...
