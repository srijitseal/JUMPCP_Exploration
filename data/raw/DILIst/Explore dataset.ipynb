# %%
import pandas as pd

# %%
df = pd.read_csv("DILIst.csv")
df
# Out:
#       DILIST_ID              CompoundName  \
# 0           191           cupric chloride
# 1           397             nitroprusside
# 2          1129             Buprenorphine
# 3            39                 cisplatin
# 4            34               carboplatin
# ...         ...                       ...
# 1149       1171            Fosfluconazole
# 1150        681              fosphenytoin
# 1151       1048  1-naphthylisothiocyanate
# 1152          1            mercaptopurine
# 1153        791                  thiotepa
#
#                                                  smiles  \
# 0                                    [Cl-].[Cl-].[Cu++]
# 1      [Fe++].[C-]#N.[C-]#N.[C-]#N.[C-]#N.[C-]#N.N#[O+]
# 2     [H][C@@]12OC3=C4C(C[C@@]5([H])N(CC6CC6)CC[C@@]...
# 3     [H][N]([H])([H])[Pt++]([Cl-])([Cl-])[N]([H])([...
# 4     [H][N]([H])([H])[Pt++]1([O-]C(=O)C2(CCC2)C(=O)...
# ...                                                 ...
# 1149  OP(O)(=O)OC(CN1C=NC=N1)(CN1C=NC=N1)C1=CC=C(F)C...
# ...
