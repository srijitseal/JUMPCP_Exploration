# %%
import pandas as pd

# %%
df = pd.read_csv("../bace/bace_processed.csv.gz", compression="gzip")
df
# Out:
#                                                  smiles        CID  Class  \
# 0     O1CC[C@@H](NC(=O)[C@@H](Cc2cc3cc(ccc3nc2N)-c2c...     BACE_1      1
# 1     Fc1cc(cc(F)c1)C[C@H](NC(=O)[C@@H](N1CC[C@](NC(...     BACE_2      1
# 2     S1(=O)(=O)N(c2cc(cc3c2n(cc3CC)CC1)C(=O)N[C@H](...     BACE_3      1
# 3     S1(=O)(=O)C[C@@H](Cc2cc(O[C@H](COCC)C(F)(F)F)c...     BACE_4      1
# 4     S1(=O)(=O)N(c2cc(cc3c2n(cc3CC)CC1)C(=O)N[C@H](...     BACE_5      1
# ...                                                 ...        ...    ...
# 1508          Clc1cc2nc(n(c2cc1)C(CC(=O)NCC1CCOCC1)CC)N  BACE_1543      0
# 1509          Clc1cc2nc(n(c2cc1)C(CC(=O)NCc1ncccc1)CC)N  BACE_1544      0
# 1510             Brc1cc(ccc1)C1CC1C=1N=C(N)N(C)C(=O)C=1  BACE_1545      0
# 1511       O=C1N(C)C(=NC(=C1)C1CC1c1cc(ccc1)-c1ccccc1)N  BACE_1546      0
# 1512                Clc1cc2nc(n(c2cc1)CCCC(=O)NCC1CC1)N  BACE_1547      0
#
#       Model     pIC50         MW   AlogP  HBA  HBD  RB  ...  PEOE8 (PEOE8)  \
# ...

# %%
df = pd.read_csv("JUMPCP_compounds_processed.csv.gz", compression="gzip")

# %%
df
# Out:
# Empty DataFrame
# Columns: [Metadata_JCP2022, smiles, Standardized_SMILES, Standardized_InChI]
# Index: []

# %%
df = pd.read_csv("../clintox/clintox_processed.csv.gz", compression="gzip")

# %%
df
# Out:
#                                                  smiles  FDA_APPROVED  CT_TOX  \
# 0     [C@@H]1([C@@H]([C@@H]([C@H]([C@@H]([C@@H]1Cl)C...             1       0
# 1     [C@H]([C@@H]([C@@H](C(=O)[O-])O)O)([C@H](C(=O)...             1       0
# 2     [H]/[NH+]=C(/C1=CC(=O)/C(=C\C=c2ccc(=C([NH3+])...             1       0
# 3     [H]/[NH+]=C(\N)/c1ccc(cc1)OCCCCCOc2ccc(cc2)/C(...             1       0
# 4     B([C@H](CC(C)C)NC(=O)[C@H](Cc1ccccc1)NC(=O)c2c...             1       0
# ...                                                 ...           ...     ...
# 1449         CS(=O)(=O)c1ccc(cc1)C2=C(C(=O)OC2)c3ccccc3             1       0
# 1450  CS(=O)(=O)CCNCC1=CC=C(O1)C2=CC3=C(C=C2)N=CN=C3...             0       1
# 1451  CS(=O)(=O)CCNCc1ccc(o1)c2ccc3c(c2)c(ncn3)Nc4cc...             1       0
# 1452  CS(=O)(=O)O.C1CO[P@@](=O)(O[C@@H]1C2=CC(=CC=C2...             0       1
# 1453                                            CS(=O)C             1       0
#
# ...
