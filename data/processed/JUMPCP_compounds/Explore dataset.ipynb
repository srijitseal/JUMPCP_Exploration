# %%
import pandas as pd

# %%
df = pd.read_csv("JUMPCP_compounds_processed.csv.gz", compression="gzip")

# %%
df
# Out:
#        Metadata_JCP2022                                             smiles  \
# 0        JCP2022_000001  CCc1nccn1-c1cccc(C2CCCN2C(=O)c2ccc(OCCN(C)C)cc...
# 1        JCP2022_000002                            OC1=NCCCN1Cc1ccc(Cl)cc1
# 2        JCP2022_000004                   CCCn1nccc1S(=O)(=O)N1CC2CCC1CNC2
# 3        JCP2022_000005  CCN=C(O)CC1N=C(c2ccc(Cl)cc2)c2cc(OC)ccc2-n2c(C...
# 4        JCP2022_000006      Cn1cc(-c2noc(-c3cc(C4CC4)n(C(C)(C)C)n3)n2)cn1
# ...                 ...                                                ...
# 115779   JCP2022_116749  CN(C)c1ccc(O)c2c1CC1CC3C(N(C)C)C(=O)C(C(=N)O)C...
# 115780   JCP2022_116750     Cc1nc(C)c(CCC(=O)N(C2CC2)C2CCCc3ccccc32)c(O)n1
# 115781   JCP2022_116751         Cn1ccc2ccn(CCN=C(O)c3cnc4ccccc4n3)c(=O)c21
# 115782   JCP2022_116752  Cc1nccc(-c2cccc(NS(=O)(=O)c3cc(C(F)(F)F)cc(C(F...
# 115783   JCP2022_116753                         COc1ccccc1C(O)=NCCN1CCOCC1
#
#                                       Standardized_SMILES  \
# ...
