# %%
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error, roc_auc_score, matthews_corrcoef, average_precision_score, confusion_matrix
from imblearn.metrics import geometric_mean_score
from imblearn.over_sampling import RandomOverSampler
from imblearn.pipeline import Pipeline
from sklearn.metrics import roc_curve
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingRandomSearchCV
from scipy.stats import randint, uniform
from pandarallel import pandarallel

import math
import sys
sys.path.append('/home/ss2686/JUMPCP')

import argparse
from scripts.evaluation_functions import evaluate_classifier, evaluate_regression, fold_error, optimize_threshold_j_statistic

# Initialize pandarallel for parallel processing
pandarallel.initialize()
import gzip

data_path = '../data/processed_splits/'
# Define the path to your gzip-compressed image_features.csv.gz file
csv_file_path = '../data/JUMP_features/JUMP_features.csv.gz'


def create_molecule_dict(csv_file_path):
    molecule_dict = {}

    with gzip.open(csv_file_path, 'rt') as f:
        next(f)  # Skip the first line (header)
        for line in f:
            data = line.strip().split(',')
            smiles = data[1]
            features = np.array(data[2:2002], dtype=float)
            molecule_dict[smiles] = features

    return molecule_dict

# Assuming you call create_molecule_dict once to create the dictionary
molecule_dict = create_molecule_dict(csv_file_path)

def generate_cellpainting(smiles):
    return molecule_dict.get(smiles, np.zeros(2000, dtype=float))

#Exammple usage:

#smiles_list = [
#    'CCc1nccn1-c1cccc(C2CCC[NH+]2C(=O)c2ccc(OCC[NH+](C)C)cc2)n1',
#    'O=C1NCCC[NH+]1Cc1ccc(Cl)cc1',
#    'O=C1NC(=O)c2cc(Nc3ccccc3)c(Nc3ccccc3)cc21',
#    'CCCn1nccc1S(=O)(=O)[NH+]1CC2CCC1C[NH2+]C2',
#    'CCNC(=O)CC1N=C(c2ccc(Cl)cc2)c2cc(OC)ccc2-n2c(C)nnc21'
#]

# Create a DataFrame with the SMILES
#smiles_df = pd.DataFrame({'SMILES': smiles_list})

#X_train = smiles_df['SMILES'].parallel_apply(generate_cellpainting)
#X_train = np.array(X_train.to_list())
#X_train

# Assuming image-based dataset is regression and others are classification
results = {}

for dataset in os.listdir(data_path):
    
    print(dataset)

    # Get all the file names for this dataset
    all_files = os.listdir(os.path.join(data_path, dataset))

    # Extract activity names by removing the _train.csv.gz or _test.csv.gz from file names
    activity_names = list(set([f.replace("_train.csv.gz", "").replace("_test.csv.gz", "") for f in all_files]))

    for activity in tqdm(activity_names, desc="Processing activities"):
        
        train_path = os.path.join(data_path, dataset, f"{activity}_train.csv.gz")
        test_path = os.path.join(data_path, dataset, f"{activity}_test.csv.gz")

        train_df = pd.read_csv(train_path, compression='gzip')#.sample(20)
        test_df = pd.read_csv(test_path, compression='gzip')#.sample(20)

        X_train = train_df['Standardized_SMILES'].parallel_apply(generate_cellpainting)
        X_train = np.array(X_train.to_list())
        
        X_test = test_df['Standardized_SMILES'].parallel_apply(generate_cellpainting)
        X_test = np.array(X_test.to_list())
        
        y_train = train_df[activity]
        y_test = test_df[activity]


        if dataset == "PK_Lombardo":
            # Regression
            regressor = RandomForestRegressor(n_jobs=-1)
            
            if activity != "fraction_unbound_in_plasma_fu":
                # Log-transform the target variable for non-"fraction_unbound_in_plasma_fu" activities
                y_train = np.log10(y_train)
                y_test = np.log10(y_test)

            print(X_train.shape)
            print(X_test.shape)
            print(len(y_train))
            print(len(y_test))
            
            # Regression
            # Define parameter search space
            param_dist_regression = {
                'max_depth': randint(10, 20),
                'max_features': randint(40, 50),
                'min_samples_leaf': randint(5, 15),
                'min_samples_split': randint(5, 15),
                'n_estimators': [200, 300, 400, 500, 600],
                'bootstrap': [True, False],
                'n_jobs': [40],
                'random_state': [42]
            }

            # Create a HalvingRandomSearchCV object
            regression_search = HalvingRandomSearchCV(
                regressor,
                param_distributions=param_dist_regression,
                factor=3,  
                cv=5,  # Number of cross-validation folds
                random_state=42,
                verbose=1,
                n_jobs=40,  # Number of parallel jobs
                scoring='neg_root_mean_squared_error'  # Scoring metric
            )

            regression_search.fit(X_train, y_train)
            best_model = regression_search.best_estimator_
            
            # Train the best model on the full training data
            best_model.fit(X_train, y_train)
            
            # Make predictions on training and test data
            predictions_train = best_model.predict(X_train)
            predictions_test = best_model.predict(X_test)

            print(len(predictions_train))
            print(len(predictions_test))
            
            
            # Calculate CV R-squared using the best model
            cv_scores = cross_val_score(best_model, X_train, y_train, cv=5, n_jobs=20, scoring='r2')

            results[activity] = {
                'CV_R2_mean': np.mean(cv_scores),
                'CV_R2_std': np.std(cv_scores),
                **evaluate_regression(y_test, predictions_test, activity)
            }
            
            
        else:
            # Classification
            model = RandomForestClassifier(n_jobs=40)
            
            # Hyperparameter Optimization
            param_dist_classification = {'max_depth': randint(10, 20),
                          'max_features': randint(40, 50),
                          'min_samples_leaf': randint(5, 15),
                          'min_samples_split': randint(5, 15),
                          'n_estimators':[200, 300, 400, 500, 600],
                          'bootstrap': [True, False],
                          'oob_score': [False],
                          'random_state': [42],
                          'criterion': ['gini', 'entropy'],
                          'n_jobs': [40],
                          'class_weight' : [None, 'balanced']
                         }
            classification_search = HalvingRandomSearchCV(
                model,
                param_dist_classification,
                factor=3,
                cv=5,
                random_state=42,
                verbose=1,
                n_jobs=40,)
            
            classification_search.fit(X_train, y_train)
            best_model = classification_search.best_estimator_
            
            # Random Over-sampling and Threshold Optimization
            sampler = RandomOverSampler(sampling_strategy='auto', random_state=42)
            
            pipeline = Pipeline(steps=[('sampler', sampler), ('model', best_model)])
            pipeline.fit(X_train, y_train)
            
            # Predict using threshold-optimized model
            predictions_train = pipeline.predict(X_train)
            probs_train = pipeline.predict_proba(X_train)[:, 1]
            probs_test = pipeline.predict_proba(X_test)[:, 1]
            
            # Use the optimize_threshold_j_statistic function to find the best threshold
            best_threshold = optimize_threshold_j_statistic(y_train, probs_train)
            #Apply the best threshold to get binary predictions on the test data
            predictions_test = (probs_test >= best_threshold).astype(int)
            
            # Calculate CV AUC using threshold-optimized model
            cv_scores = cross_val_score(pipeline, X_train, y_train, cv=5, n_jobs=-1, scoring='roc_auc')

            results[activity] = {
                'CV_AUC_mean': np.mean(cv_scores),
                'CV_AUC_std': np.std(cv_scores),
                **evaluate_classifier(y_test, predictions_test, probs_test)
            }
                  
        # Save results at each step
        pd.DataFrame(results).T.to_csv('./image_based_model_results.csv')
        
        #break
        
    #break
            
        

# Save results
results_df = pd.DataFrame(results).T.reset_index(drop=False)
results_df = results_df.rename(columns={'index': 'endpoint'})
results_df.to_csv('./cellpainting_model_results.csv', index=False)
# Out:
# INFO: Pandarallel will run on 56 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# toxcast
# Processing activities:   0%|                            | 0/331 [00:00<?, ?it/s]
# n_iterations: 3
# n_required_iterations: 3
# n_possible_iterations: 3
# min_resources_: 20
# max_resources_: 282
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 14
# n_resources: 20
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# ----------
# iter: 1
# n_candidates: 5
# n_resources: 60
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ----------
# iter: 2
# n_candidates: 2
# n_resources: 180
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# Processing activities:   0%|                  | 1/331 [00:18<1:41:31, 18.46s/it]Exception ignored in: <function _releaseLock at 0x2ac274d4cca0>
# Traceback (most recent call last):
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/logging/__init__.py", line 227, in _releaseLock
#     def _releaseLock():
# KeyboardInterrupt:
# Process ForkPoolWorker-593:
# Exception ignored in: <Finalize object, dead>
# Traceback (most recent call last):
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 692, in _terminate_pool
#     cls._help_stuff_finish(inqueue, task_handler, len(pool))
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 672, in _help_stuff_finish
#     inqueue._rlock.acquire()
# KeyboardInterrupt:
# Process ForkPoolWorker-588:
# Process ForkPoolWorker-589:
# Process ForkPoolWorker-597:
# Process ForkPoolWorker-582:
# Process ForkPoolWorker-604:
# Process ForkPoolWorker-586:
# Process ForkPoolWorker-587:
# Process ForkPoolWorker-576:
# Process ForkPoolWorker-578:
# Process ForkPoolWorker-573:
# Process ForkPoolWorker-575:
# Process ForkPoolWorker-581:
# Traceback (most recent call last):
# Process ForkPoolWorker-572:
# Process ForkPoolWorker-598:
# Process ForkPoolWorker-601:
# Process ForkPoolWorker-596:
# Process ForkPoolWorker-603:
# Traceback (most recent call last):
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Process ForkPoolWorker-574:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Process ForkPoolWorker-592:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Process ForkPoolWorker-602:
# Process ForkPoolWorker-583:
# Process ForkPoolWorker-600:
# Traceback (most recent call last):
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Process ForkPoolWorker-595:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Process ForkPoolWorker-594:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-585:
# Traceback (most recent call last):
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Process ForkPoolWorker-591:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-577:
# Traceback (most recent call last):
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-590:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-584:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-580:
# Process ForkPoolWorker-579:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-571:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
# Process ForkPoolWorker-599:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Process ForkPoolWorker-570:
# Traceback (most recent call last):
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# Traceback (most recent call last):
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 366, in get
#     res = self._reader.recv_bytes()
# KeyboardInterrupt
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
# KeyboardInterrupt
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/connection.py", line 221, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# Processing activities:   0%|                  | 1/331 [00:29<2:39:49, 29.06s/it]
# n_iterations: 5
# n_required_iterations: 5
# n_possible_iterations: 5
# min_resources_: 20
# max_resources_: 1970
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 98
# n_resources: 20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [21], in <cell line: 72>()
#     168 param_dist_classification = {'max_depth': randint(10, 20),
#     169               'max_features': randint(40, 50),
#     170               'min_samples_leaf': randint(5, 15),
#    (...)
#     178               'class_weight' : [None, 'balanced']
#     179              }
#     180 classification_search = HalvingRandomSearchCV(
#     181     model,
#     182     param_dist_classification,
#    (...)
#     186     verbose=1,
#     187     n_jobs=40,)
# --> 189 classification_search.fit(X_train, y_train)
#     190 best_model = classification_search.best_estimator_
#     192 # Random Over-sampling and Threshold Optimization
#
# File ~/miniconda3/envs/my-rdkit-env/lib/python3.9/site-packages/sklearn/model_selection/_search_successive_halving.py:261, in BaseSuccessiveHalving.fit(self, X, y, groups, **fit_params)
#     253 self._check_input_parameters(
#     254     X=X,
#     255     y=y,
#     256     groups=groups,
#     257 )
#     259 self._n_samples_orig = _num_samples(X)
# --> 261 super().fit(X, y=y, groups=groups, **fit_params)
#     263 # Set best_score_: BaseSearchCV does not set it, as refit is a callable
#     264 self.best_score_ = self.cv_results_["mean_test_score"][self.best_index_]
#
# File ~/miniconda3/envs/my-rdkit-env/lib/python3.9/site-packages/sklearn/model_selection/_search.py:875, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     869     results = self._format_results(
#     870         all_candidate_params, n_splits, all_out, all_more_results
#     871     )
#     873     return results
# --> 875 self._run_search(evaluate_candidates)
#     877 # multimetric is determined here because in the case of a callable
#     878 # self.scoring the return type is only known after calling
#     879 first_test_score = all_out[0]["test_scores"]
#
# File ~/miniconda3/envs/my-rdkit-env/lib/python3.9/site-packages/sklearn/model_selection/_search_successive_halving.py:366, in BaseSuccessiveHalving._run_search(self, evaluate_candidates)
#     359     cv = self._checked_cv_orig
#     361 more_results = {
#     362     "iter": [itr] * n_candidates,
#     363     "n_resources": [n_resources] * n_candidates,
#     364 }
# --> 366 results = evaluate_candidates(
#     367     candidate_params, cv, more_results=more_results
#     368 )
#     370 n_candidates_to_keep = ceil(n_candidates / self.factor)
#     371 candidate_params = _top_k(results, n_candidates_to_keep, itr)
#
# File ~/miniconda3/envs/my-rdkit-env/lib/python3.9/site-packages/sklearn/model_selection/_search.py:811, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     809 def evaluate_candidates(candidate_params, cv=None, more_results=None):
#     810     cv = cv or cv_orig
# --> 811     candidate_params = list(candidate_params)
#     812     n_candidates = len(candidate_params)
#     814     if self.verbose > 0:
#
# File ~/miniconda3/envs/my-rdkit-env/lib/python3.9/site-packages/sklearn/model_selection/_search.py:324, in ParameterSampler.__iter__(self)
#     322 for k, v in items:
#     323     if hasattr(v, "rvs"):
# --> 324         params[k] = v.rvs(random_state=rng)
#     325     else:
#     326         params[k] = v[rng.randint(len(v))]
#
# KeyboardInterrupt:

# %%
results_df
# Out:
#              endpoint  CV_AUC_mean  CV_AUC_std  Held_out_AUC  Held_out_AUCPR  \
# 0  BSK_BE3C_IL1a_down     0.490435    0.136015       0.39548        0.147838
#
#    Held_out_BA  Held_out_FN  Held_out_FP  Held_out_MCC  Held_out_Sensitivity  \
# 0          0.5         12.0          0.0           0.0                   0.0
#
#    Held_out_Specificity  Held_out_TN  Held_out_TP
# 0                   1.0         59.0          0.0
