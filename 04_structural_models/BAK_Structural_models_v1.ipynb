# %%
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
from rdkit import Chem, DataStructs
from rdkit.Chem import AllChem
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error, roc_auc_score, matthews_corrcoef, average_precision_score, confusion_matrix
from sklearn.model_selection import GridSearchCV
from imblearn.metrics import geometric_mean_score
from imblearn.over_sampling import RandomOverSampler
from imblearn.pipeline import Pipeline


def generate_fingerprints(smiles_list):
    fps = []
    for smiles in smiles_list:
        mol = Chem.MolFromSmiles(smiles)
        fp = AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=2048)
        arr = np.zeros((1,))
        DataStructs.ConvertToNumpyArray(fp, arr)
        fps.append(arr)
    return np.array(fps)

def evaluate_classifier(true_labels, predictions, probs):
    ba 
    auc = roc_auc_score(true_labels, probs)
    mcc = matthews_corrcoef(true_labels, predictions)
    avg_precision = average_precision_score(true_labels, probs)
    tn, fp, fn, tp = confusion_matrix(true_labels, predictions).ravel()
    spe = tn / (tn + fp)
    sen = tp / (tp + fn)
    ba = (spe + sen)/2
    return {'Held_out_TP': tp, 'Held_out_TN': tn,
            'Held_out_FP': fp, 'Held_out_FN': fn,
            'Held_out_BA': ba,
            'Held_out_AUC': auc, 'Held_out_MCC': mcc, 
            'Held_out_AUCPR': avg_precision, 'Held_out_Specificity': spe,
            'Held_out_Sensitivity': sen}

def fold_error(true_values, predictions):
    ratio = predictions / true_values
    adjusted_ratio = np.where(ratio < 1, 1/ratio, ratio)
    return adjusted_ratio

def evaluate_regression(true_values, predictions):
    rmse = np.sqrt(mean_squared_error(true_values, predictions))
    r2 = np.corrcoef(true_values, predictions)[0, 1] ** 2
    ratio = predictions / true_values
    avg_fold_error = np.mean(fold_error(true_values, predictions))

    return {'Held_out_R2': r2, 'Held_out_RMSE': rmse, "Held_out_average_fold_error": avg_fold_error}

# Path where your data is stored
data_path = '../data/processed_splits/'

results = {}

# Assuming PK dataset is regression and others are classification
for dataset in os.listdir(data_path):
    print(dataset)
    
    # Get all the file names for this dataset
    all_files = os.listdir(os.path.join(data_path, dataset))

    # Extract activity names by removing the _train.csv.gz or _test.csv.gz from file names
    activity_names = list(set([f.replace("_train.csv.gz", "").replace("_test.csv.gz", "") for f in all_files]))

    for activity in tqdm(activity_names, desc="Processing activities"):
        print(activity)
        
        train_path = os.path.join(data_path, dataset, f"{activity}_train.csv.gz")
        test_path = os.path.join(data_path, dataset, f"{activity}_test.csv.gz")

        train_df = pd.read_csv(train_path, compression='gzip')
        test_df = pd.read_csv(test_path, compression='gzip')

        X_train = generate_fingerprints(train_df['Standardized_SMILES'])
        X_test = generate_fingerprints(test_df['Standardized_SMILES'])

        y_train = train_df[activity]
        y_test = test_df[activity]

        if dataset == "PK_Lombardo":
            model = RandomForestRegressor(n_jobs=-1)
            model.fit(X_train, y_train)
            predictions_train = model.predict(X_train)
            predictions_test = model.predict(X_test)

            cv_scores = cross_val_score(model, X_train, y_train, n_jobs=-1, cv=5, scoring='r2')

            results[activity] = {
                'CV_R2_mean': np.mean(cv_scores),
                'CV_R2_std': np.std(cv_scores),
                **evaluate_regression(y_test, predictions_test)
            }
        else:
            model = RandomForestClassifier(n_jobs=-1)
            model.fit(X_train, y_train)
            predictions_train = model.predict(X_train)
            predictions_test = model.predict(X_test)
            probs_test = model.predict_proba(X_test)[:, 1]

            cv_scores = cross_val_score(model, X_train, y_train, n_jobs=-1, cv=5, scoring='roc_auc')

            results[activity] = {
                'CV_AUC_mean': np.mean(cv_scores),
                'CV_AUC_std': np.std(cv_scores),
                **evaluate_classifier(y_test, predictions_test, probs_test)
            }
            
        # Save results at each step
        pd.DataFrame(results).T.to_csv('./structural_model_results.csv')
            
        #break
    #break

# Save results
pd.DataFrame(results).T.to_csv('./structural_model_results.csv')
# Out:
# toxcast
# ATG_TGFb_CIS_dn
# OT_ER_ERbERb_0480
# BSK_LPS_SRB_down
# BSK_hDFCGF_EGFR_down
# ATG_VDRE_CIS_up
# CEETOX_H295R_11DCORT_dn
# CEETOX_H295R_ESTRADIOL_up
# Tanguay_ZF_120hpf_SNOU_up
# ATG_GATA_CIS_dn
# BSK_CASM3C_HLADR_down
# BSK_CASM3C_uPAR_down
# Tanguay_ZF_120hpf_MORT_up
# ATG_E_Box_CIS_up
# BSK_LPS_MCSF_down
# TOX21_ERa_BLA_Antagonist_ch1
# ATG_TAL_CIS_up
# BSK_KF3CT_IP10_down
# TOX21_NFkB_BLA_agonist_ch2
# NCCT_QuantiLum_inhib_2_dn
# APR_HepG2_MitoMass_72h_dn
# BSK_3C_IL8_down
# APR_HepG2_StressKinase_24h_up
# BSK_KF3CT_TIMP2_down
# NVS_NR_bER
# BSK_hDFCGF_IP10_down
# BSK_hDFCGF_TIMP1_down
# ATG_DR4_LXR_CIS_dn
# Tanguay_ZF_120hpf_PE_up
# CEETOX_H295R_ANDR_dn
# TOX21_HSE_BLA_agonist_ch2
# Tanguay_ZF_120hpf_JAW_up
# TOX21_GR_BLA_Agonist_ch1
# APR_HepG2_CellLoss_24h_dn
# ATG_PPARd_TRANS_up
# NVS_NR_hPPARg
# TOX21_VDR_BLA_Agonist_viability
# ATG_RXRb_TRANS_up
# APR_HepG2_MitoMembPot_72h_dn
# TOX21_p53_BLA_p5_ch1
# BSK_LPS_MCP1_down
# TOX21_AutoFluor_HEPG2_Media_blue
# BSK_KF3CT_MMP9_down
# ATG_CRE_CIS_up
# TOX21_p53_BLA_p2_viability
# APR_HepG2_CellCycleArrest_24h_dn
# TOX21_HSE_BLA_agonist_viability
# TOX21_PPARd_BLA_Antagonist_ch1
# BSK_3C_TissueFactor_down
# TOX21_PPARg_BLA_antagonist_ratio
# ATG_PPARa_TRANS_up
# TOX21_AhR_LUC_Agonist
# CEETOX_H295R_CORTISOL_dn
# ATG_RORE_CIS_up
# OT_ER_ERaERa_1440
# ATG_STAT3_CIS_dn
# NVS_NR_hGR
# TOX21_PPARd_BLA_Agonist_viability
# TOX21_FXR_BLA_Antagonist_ch2
# BSK_BE3C_MIG_down
# TOX21_p53_BLA_p5_ch2
# ATG_SREBP_CIS_up
# TOX21_VDR_BLA_Antagonist_ch1
# NHEERL_ZF_144hpf_TERATOSCORE_up
# BSK_CASM3C_MCP1_down
# TOX21_GR_BLA_Agonist_ratio
# TOX21_FXR_BLA_Antagonist_ch1
# BSK_3C_Vis_down
# NVS_NR_mERa
# BSK_BE3C_MMP1_up
# ATG_GRE_CIS_dn
# BSK_BE3C_SRB_down
# TOX21_NFkB_BLA_agonist_viability
# APR_HepG2_MitoMembPot_24h_dn
# APR_HepG2_MitoMass_72h_up
# ATG_IR1_CIS_up
# TOX21_MMP_ratio_up
# BSK_LPS_CD40_down
# ATG_PPARg_TRANS_up
# APR_HepG2_MitoMass_24h_dn
# TOX21_p53_BLA_p4_ch1
# TOX21_AutoFluor_HEPG2_Cell_blue
# ATG_PPRE_CIS_up
# ATG_NRF2_ARE_CIS_up
# TOX21_AR_BLA_Agonist_ratio
# BSK_4H_uPAR_down
# ATG_XTT_Cytotoxicity_up
# ATG_CAR_TRANS_dn
# TOX21_p53_BLA_p3_ch1
# Tanguay_ZF_120hpf_EYE_up
# TOX21_HSE_BLA_agonist_ch1
# TOX21_PPARd_BLA_agonist_ratio
# OT_NURR1_NURR1RXRa_0480
# TOX21_p53_BLA_p1_ch2
# BSK_hDFCGF_MCSF_down
# TOX21_VDR_BLA_agonist_ch2
# TOX21_p53_BLA_p4_viability
# CEETOX_H295R_PROG_up
# BSK_hDFCGF_SRB_down
# TOX21_AR_LUC_MDAKB2_Agonist
# TOX21_FXR_BLA_antagonist_ratio
# OT_AR_ARSRC1_0480
# APR_HepG2_p53Act_72h_up
# BSK_CASM3C_TissueFactor_down
# BSK_4H_VEGFRII_down
# TOX21_p53_BLA_p5_ratio
# BSK_3C_ICAM1_down
# ATG_Myb_CIS_dn
# TOX21_TR_LUC_GH3_Antagonist
# BSK_BE3C_MMP1_down
# BSK_SAg_SRB_down
# BSK_CASM3C_IL8_down
# BSK_3C_Thrombomodulin_up
# BSK_3C_HLADR_down
# BSK_LPS_PGE2_down
# BSK_4H_VCAM1_down
# TOX21_PPARg_BLA_Agonist_ratio
# ATG_CMV_CIS_up
# BSK_CASM3C_Proliferation_down
# TOX21_p53_BLA_p2_ratio
# APR_HepG2_CellLoss_72h_dn
# ATG_ISRE_CIS_dn
# TOX21_ERa_LUC_BG1_Antagonist
# BSK_KF3CT_SRB_down
# ATG_p53_CIS_dn
# BSK_SAg_PBMCCytotoxicity_down
# TOX21_AutoFluor_HEK293_Media_blue
# ATG_FoxO_CIS_dn
# BSK_3C_MIG_down
# ATG_RARb_TRANS_dn
# ATG_ERa_TRANS_up
# TOX21_AR_BLA_Antagonist_ch2
# BSK_KF3CT_MCP1_down
# BSK_4H_Eotaxin3_down
# TOX21_p53_BLA_p4_ratio
# ATG_NF_kB_CIS_dn
# TOX21_NFkB_BLA_agonist_ratio
# ATG_C_EBP_CIS_up
# ATG_Sp1_CIS_up
# TOX21_Aromatase_Inhibition
# TOX21_ERa_LUC_BG1_Agonist
# BSK_3C_VCAM1_down
# TOX21_ERa_BLA_Antagonist_ratio
# BSK_3C_uPAR_down
# BSK_3C_Eselectin_down
# CEETOX_H295R_OHPROG_dn
# BSK_CASM3C_MCSF_down
# OT_FXR_FXRSRC1_1440
# BSK_4H_SRB_down
# OT_ER_ERaERa_0480
# TOX21_p53_BLA_p3_ch2
# ATG_DR5_CIS_dn
# OT_AR_ARSRC1_0960
# TOX21_ESRE_BLA_ch1
# TOX21_AR_BLA_Antagonist_ratio
# TOX21_ERa_BLA_Agonist_ch2
# NCCT_QuantiLum_inhib_dn
# TOX21_ERa_BLA_Agonist_ch1
# BSK_CASM3C_Thrombomodulin_up
# ATG_E2F_CIS_dn
# ATG_PXR_TRANS_up
# OT_NURR1_NURR1RXRa_1440
# BSK_CASM3C_LDLR_down
# CEETOX_H295R_ESTRONE_up
# TOX21_VDR_BLA_antagonist_ratio
# OT_AR_ARELUC_AG_1440
# ATG_Sox_CIS_up
# BSK_4H_Pselectin_down
# BSK_LPS_VCAM1_down
# Tanguay_ZF_120hpf_YSE_up
# BSK_hDFCGF_PAI1_down
# ATG_Ets_CIS_dn
# TOX21_ESRE_BLA_ratio
# TOX21_AR_BLA_Agonist_ch2
# ATG_IR1_CIS_dn
# TOX21_ELG1_LUC_Agonist
# BSK_hDFCGF_MMP1_down
# BSK_KF3CT_ICAM1_down
# ATG_DR5_CIS_up
# TOX21_GR_BLA_Agonist_ch2
# APR_HepG2_p53Act_24h_up
# BSK_hDFCGF_IL8_down
# Tanguay_ZF_120hpf_BRAI_up
# BSK_SAg_Eselectin_down
# TOX21_GR_BLA_Antagonist_ch2
# BSK_LPS_Eselectin_down
# ATG_LXRa_TRANS_up
# ATG_PBREM_CIS_up
# BSK_BE3C_HLADR_down
# TOX21_PPARd_BLA_agonist_ch2
# BSK_CASM3C_VCAM1_down
# BSK_CASM3C_MIG_down
# TOX21_p53_BLA_p3_ratio
# BSK_SAg_MIG_down
# ATG_Ahr_CIS_dn
# TOX21_FXR_BLA_antagonist_viability
# TOX21_NFkB_BLA_agonist_ch1
# TOX21_ESRE_BLA_viability
# BSK_CASM3C_SAA_down
# TOX21_p53_BLA_p3_viability
# ATG_NF_kB_CIS_up
# APR_HepG2_StressKinase_72h_up
# BSK_LPS_PGE2_up
# OT_ER_ERaERb_0480
# CEETOX_H295R_DOC_dn
# BSK_LPS_TNFa_up
# ATG_Oct_MLP_CIS_up
# ACEA_T47D_80hr_Positive
# BSK_hDFCGF_Proliferation_down
# APR_HepG2_MicrotubuleCSK_72h_dn
# TOX21_ERa_BLA_Antagonist_viability
# ATG_NURR1_TRANS_up
# ATG_PXRE_CIS_up
# ATG_GAL4_TRANS_dn
# BSK_SAg_CD69_down
# ATG_M_19_CIS_dn
# TOX21_FXR_BLA_agonist_ratio
# TOX21_ARE_BLA_agonist_ratio
# TOX21_AutoFluor_HEK293_Cell_blue
# TOX21_p53_BLA_p2_ch2
# TOX21_GR_BLA_Antagonist_ratio
# TOX21_ERa_BLA_Antagonist_ch2
# BSK_BE3C_IP10_down
# OT_ER_ERbERb_1440
# TOX21_p53_BLA_p5_viability
# ATG_HSE_CIS_up
# BSK_CASM3C_LDLR_up
# ATG_RXRb_TRANS_dn
# ATG_CMV_CIS_dn
# ATG_Pax6_CIS_up
# BSK_BE3C_IL1a_down
# BSK_BE3C_uPA_down
# BSK_3C_Proliferation_down
# ATG_THRa1_TRANS_up
# OT_ERa_EREGFP_0480
# ATG_Xbp1_CIS_up
# TOX21_ERa_BLA_Agonist_ratio
# TOX21_AR_LUC_MDAKB2_Antagonist
# Tanguay_ZF_120hpf_ActivityScore
# OT_ER_ERaERb_1440
# BSK_hDFCGF_CollagenIII_down
# ATG_GR_TRANS_up
# NCCT_HEK293T_CellTiterGLO
# BSK_BE3C_tPA_down
# APR_HepG2_MicrotubuleCSK_72h_up
# TOX21_HSE_BLA_agonist_ratio
# BSK_hDFCGF_VCAM1_down
# APR_HepG2_OxidativeStress_72h_up
# ATG_E_Box_CIS_dn
# BSK_3C_SRB_down
# BSK_SAg_IL8_down
# BSK_KF3CT_uPA_down
# ATG_AP_2_CIS_dn
# TOX21_MMP_ratio_down
# CEETOX_H295R_OHPREG_up
# NVS_NR_hER
# ATG_ERE_CIS_dn
# TOX21_AR_BLA_Antagonist_viability
# TOX21_VDR_BLA_antagonist_viability
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [8], in <cell line: 52>()
#      89 else:
#      90     model = RandomForestClassifier(n_jobs=-1)
# ---> 91     model.fit(X_train, y_train)
#      92     predictions_train = model.predict(X_train)
#      93     predictions_test = model.predict(X_test)
#
# File ~/miniconda3/envs/my-rdkit-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:476, in BaseForest.fit(self, X, y, sample_weight)
#     465 trees = [
#     466     self._make_estimator(append=False, random_state=random_state)
#     467     for i in range(n_more_estimators)
#     468 ]
#     470 # Parallel loop: we prefer the threading backend as the Cython code
#     471 # for fitting the trees is internally releasing the Python GIL
#     472 # making threading more efficient than multiprocessing in
#     473 # that case. However, for joblib 0.12+ we respect any
#     474 # parallel_backend contexts set at a higher level,
#     475 # since correctness does not rely on using threads.
# --> 476 trees = Parallel(
#     477     n_jobs=self.n_jobs,
#     478     verbose=self.verbose,
#     479     prefer="threads",
#     480 )(
#     481     delayed(_parallel_build_trees)(
#     482         t,
#     483         self.bootstrap,
#     484         X,
#     485         y,
#     486         sample_weight,
#     487         i,
#     488         len(trees),
#     489         verbose=self.verbose,
#     490         class_weight=self.class_weight,
#     491         n_samples_bootstrap=n_samples_bootstrap,
#     492     )
#     493     for i, t in enumerate(trees)
#     494 )
#     496 # Collect newly grown trees
#     497 self.estimators_.extend(trees)
#
# File ~/miniconda3/envs/my-rdkit-env/lib/python3.9/site-packages/joblib/parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File ~/miniconda3/envs/my-rdkit-env/lib/python3.9/site-packages/joblib/parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File ~/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py:765, in ApplyResult.get(self, timeout)
#     764 def get(self, timeout=None):
# --> 765     self.wait(timeout)
#     766     if not self.ready():
#     767         raise TimeoutError
#
# File ~/miniconda3/envs/my-rdkit-env/lib/python3.9/multiprocessing/pool.py:762, in ApplyResult.wait(self, timeout)
#     761 def wait(self, timeout=None):
# --> 762     self._event.wait(timeout)
#
# File ~/miniconda3/envs/my-rdkit-env/lib/python3.9/threading.py:574, in Event.wait(self, timeout)
#     572 signaled = self._flag
#     573 if not signaled:
# --> 574     signaled = self._cond.wait(timeout)
#     575 return signaled
#
# File ~/miniconda3/envs/my-rdkit-env/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %%
pd.DataFrame(results).T.to_csv('./structural_model_results.csv')

# %%
df = pd.read_csv("structural_model_results.csv")
df
# Out:
#                             Unnamed: 0  CV_AUC_mean  CV_AUC_std  Held_out_TP  \
# 0                      ATG_TGFb_CIS_dn     0.665075    0.160983          0.0
# 1                    OT_ER_ERbERb_0480     0.756698    0.080058          4.0
# 2                     BSK_LPS_SRB_down     0.676473    0.049920          3.0
# 3                 BSK_hDFCGF_EGFR_down     0.521239    0.096812          0.0
# 4                      ATG_VDRE_CIS_up     0.727780    0.045614         13.0
# ..                                 ...          ...         ...          ...
# 252               TOX21_MMP_ratio_down     0.772067    0.061959          8.0
# 253             CEETOX_H295R_OHPREG_up     0.866917    0.139270          1.0
# 254                         NVS_NR_hER     0.706179    0.089204          6.0
# 255                     ATG_ERE_CIS_dn     0.637666    0.072744          0.0
# 256  TOX21_AR_BLA_Antagonist_viability     0.724166    0.025688          4.0
#
#      Held_out_TN  Held_out_FP  Held_out_FN  Held_out_AUC  Held_out_MCC  \
# 0          137.0          0.0          5.0      0.468613      0.000000
# 1           72.0          0.0          9.0      0.948184      0.522976
# 2           46.0          6.0         16.0      0.655870      0.056566
# 3           64.0          2.0          5.0      0.531818     -0.046860
# 4           88.0         10.0         31.0      0.687152      0.242767
# ..           ...          ...          ...           ...           ...
# 252        158.0          2.0         32.0      0.856641      0.344124
# 253         18.0          1.0          5.0      0.684211      0.179520
# 254         43.0          2.0         12.0      0.780247      0.391965
# 255        131.0          0.0         11.0      0.523942      0.000000
# 256        454.0          3.0         32.0      0.761245      0.229907
#
#      Held_out_AUCPR  Held_out_Specificity  Held_out_Sensitivity
# 0          0.036171              1.000000              0.000000
# 1          0.774826              1.000000              0.307692
# 2          0.396557              0.884615              0.157895
# 3          0.113358              0.969697              0.000000
# 4          0.465068              0.897959              0.295455
# ..              ...                   ...                   ...
# 252        0.627194              0.987500              0.200000
# 253        0.457388              0.947368              0.166667
# 254        0.621444              0.955556              0.333333
# 255        0.172752              1.000000              0.000000
# 256        0.257979              0.993435              0.111111
#
# [257 rows x 12 columns]

# %%
df["BA"] = (df["Held_out_Specificity"]+df["Held_out_Sensitivity"])/2

# %%
df.sort_values("BA")
# Out:
#                     Unnamed: 0  CV_AUC_mean  CV_AUC_std  Held_out_TP  \
# 155    NCCT_QuantiLum_inhib_dn     0.722778    0.126442          6.0
# 55                  NVS_NR_hGR     0.447628    0.159549         15.0
# 78   APR_HepG2_MitoMass_24h_dn     0.529304    0.101934          0.0
# 91     OT_NURR1_NURR1RXRa_0480     0.591394    0.122119          0.0
# 28        CEETOX_H295R_ANDR_dn     0.596118    0.107801          1.0
# ..                         ...          ...         ...          ...
# 53           OT_ER_ERaERa_1440     0.798622    0.105112          3.0
# 82         ATG_NRF2_ARE_CIS_up     0.694991    0.013168         30.0
# 178   TOX21_GR_BLA_Agonist_ch2     0.808838    0.058552         10.0
# 211            ATG_PXRE_CIS_up     0.718595    0.039401         43.0
# 240            ATG_GR_TRANS_up     0.875780    0.068336          6.0
#
#      Held_out_TN  Held_out_FP  Held_out_FN  Held_out_AUC  Held_out_MCC  \
# 155          3.0          6.0          6.0      0.324074     -0.166667
# 55           0.0          5.0          1.0      0.618750     -0.125000
# 78          46.0          3.0          9.0      0.664399     -0.100093
# 91          71.0          3.0         12.0      0.746622     -0.076559
# 28          14.0          2.0         10.0      0.329545     -0.053300
# ..           ...          ...          ...           ...           ...
# 53          72.0          0.0          5.0      0.967014      0.592157
# 82          74.0         12.0         26.0      0.769830      0.424239
# 178        468.0          1.0         14.0      0.755730      0.603994
# 211         64.0          9.0         26.0      0.840679      0.518617
# 240        136.0          0.0          0.0      1.000000      1.000000
#
#      Held_out_AUCPR  Held_out_Specificity  Held_out_Sensitivity        BA
# 155        0.476993              0.333333              0.500000  0.416667
# 55         0.823696              0.000000              0.937500  0.468750
# 78         0.242604              0.938776              0.000000  0.469388
# 91         0.268119              0.959459              0.000000  0.479730
# 28         0.349558              0.875000              0.090909  0.482955
# ..              ...                   ...                   ...       ...
# 53         0.829657              1.000000              0.375000  0.687500
# 82         0.626114              0.860465              0.535714  0.698090
# 178        0.517021              0.997868              0.416667  0.707267
# 211        0.843551              0.876712              0.623188  0.749950
# 240        1.000000              1.000000              1.000000  1.000000
#
# [257 rows x 13 columns]

# %%
df[df["Unnamed: 0"]=="ATG_C_EBP_CIS_up"]
# Out:
#            Unnamed: 0  CV_AUC_mean  CV_AUC_std  Held_out_TP  Held_out_TN  \
# 136  ATG_C_EBP_CIS_up     0.718569    0.087868          1.0        128.0
#
#      Held_out_FP  Held_out_FN  Held_out_AUC  Held_out_MCC  Held_out_AUCPR  \
# 136          1.0         12.0        0.5322      0.169283        0.150225
#
#      Held_out_Specificity  Held_out_Sensitivity        BA
# 136              0.992248              0.076923  0.534586
